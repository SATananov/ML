# %%
# Write your imports here

# %% [markdown]
# # Linear Regression, Regularization and Testing Exercise
# # ML basics, selecting, evaluating, and comparing models

# %% [markdown]
# In this exercise, we'll work with the Big Mart dataset from [Kaggle](https://www.kaggle.com/datasets/shivan118/big-mart-sales-prediction-datasets).
#
# For the purposes of the exercise, since we're not submitting anything to the contest that Kaggle's running, we can focus on the `train.csv` file only. Our goal is to predict sales (`Item_Outlet_Sales`) given the item ID and outlet (store) ID.
#
# _Note:_ If you find the task too difficult, you may ignore the outlet ID column from your analysis. I **DO NOT** recommend you do, since it affects the outcome, but _some_ analysis is better than none.
#
# _Note 2:_ You may need to do a significant amount of research before you get your exercise to a "good" level of metrics.
#
# _Note 3:_ If you follow the exercise exactly, your data preprocessing and experiments will become a bit messy.  You don't need to obther with data pipelines now. We'll learn ways to make everything tidier later on in the course.

# %% [markdown]
# ### Problem 1. Formulate the research question
# What do we want to achieve? Think about hypothesis testing, but on a larger scale. Write down, in plain text, what your desired outcomes are from a business (domain) perspective AND from a data science perspective. Think about metrics, expected results, etc. You should do all of this BEFORE you get to know your data!

# %%
# Write your code here

# %% [markdown]
# ### Problem 2. Read and explore the dataset
# You know what to do! Perform EDA, think about outliers, special values; try to form and defend hypotheses.

# %%
# Write your code here

# %% [markdown]
# ### Problem 3. Baseline model... Not yet!
# We can always do a quick and dirty linear regression. However, we'll need to do a bit of data preprocessing.
#
# Every model in `scikit-learn` "wants" to only work with numbers. Find a way (or ways) to do this. Look at the `sklearn.preprocessing` module for ideas.

# %%
# Write your code here

# %% [markdown]
# ### Problem 4. Baseline model... Just a second!
# Split the data into training and testing sets. Think about (cross-)validation too. How should you do the splits? Write your decision and support it with evidence. Don't forget about reproducibility and writing everything down! :)
#
# Now go back to the last problem and decide _how_, and _in what order_ you should do splitting and preprocessing. Write your thoughts and results.

# %%
# Write your code here

# %% [markdown]
# ### Problem 5. Baseline model... Finally!
# Train a linear regression. That's it.

# %%
# Write your code here

# %% [markdown]
# ### Problem 6. Evaluation
# Use at least three different metrics, at least one of which should be "visual", about how your model performs. Discuss the results.
#
# Suggest routes for improvement.
#
# * Optionally, provide a way to interpret the model. If you've done exercises 3 and 4 properly, you should have a very convenient, very easy wayto directly understand what the model is doing. You could use that to compare against your thoughts about what it _should_ be doing, and get many ideas for debugging and improvement.

# %%
# Write your code here

# %% [markdown]
# ### Problem 7. A different regression model
# Linear regression is pretty simple - which is both good and bad. Try out a different regressor of your choice. You can look at `scikit-learn`'s docs for inspiration.
#
# Don't forget to evaluate it _the same way_ as the previous one. For a better model, you should get comparable, or better results. :)

# %%
# Write your code here

# %% [markdown]
# ### Problem 8. Hyperparameter tuning
# Select at least two hyperparameters that are important for your model. Construct a parameter grid and perform tuning.
#
# You can follow the process we've established, or you can slightly diverge from it: your call.

# %%
# Write your code here

# %% [markdown]
# ### * Problem 9. Evaluate and iterate!
# Now, you should be left with a slightly better model, at least on paper. Try to see whether it's really this good, or the relatively small dataset keeps deceiving you. Try to find other ways to evaluate and improve what you already have. Write your results, and discuss the pros and cons of the new model vs. the baseline one.
#
# Once again, make your research quantifiable. Think about the hypothesis testing process and try to avoid wild assumptions. Ask questions about the data, and don't forget to doubt even oyour own methods.

# %%
# Write your code here

# %% [markdown]
# ### Problem 10. Change the data preprocessing and try again
# At this point, you'll likely regret one of your data preprocessing decisions earlier on in problems 3 and 4. You can always change the data pipeline and run new models.
#
# Make one significant change (it might be feature selection, feature engineering, different preprocessing steps, scaling, adding more features, treating outliers / missing values in a different way, maybe evem multiple processing steps)... and run everything again. If your ML process was set up well at the beginning, you'd have no problem with reproduciiblity; and you'll be able to directly compare your changes and how they affect the entire research question.
#
# I suggest you do this below, or in a different notebook. If you edit the cells below, you'll lose work, which is... horrible.

# %%
# Write your code here
